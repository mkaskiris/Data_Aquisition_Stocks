# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('complete_mean_30.csv', parse_dates=True, index_col='Unnamed: 0')
df.columns = ['apple', 'sp500', 'mic', 'goog', 'amz', 'volume', 'price',
       'covid', 'dif', 'event']

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Hypothesis: Events do not increase stock price

# %%
dfm['event_return'] = dfm.apple.pct_change(7)

# %%
print(dfm.apple.pct_change(periods=7).mean())
print(dfm.apple.pct_change(periods=7).std())
# Out:
# 0.045374164554751475
# 1.3184078335855105

# %%
plt.figure(figsize=(16,8))
plt.subplot(121)
sns.histplot(dfm[dfm['event'] == 1]['event_return'],color='green',bins=10, kde=True)
plt.xlabel('Event')
plt.subplot(122)
sns.histplot(dfm[dfm['event'] == 0]['event_return'],color='green',bins=100, kde=True)
plt.xlabel('No event')
print('Mean after even: {:.4f}'.format(dfm[dfm['event'] == 1]['event_return'].mean()))
print('General Mean: {:.4f}'.format(dfm[dfm['event'] == 0]['event_return'].mean()))
# Out:
# Mean after even: 0.0092
# General Mean: 0.0457

# %%
sns.histplot(dfm[dfm['event'] == 0]['event_return'],color='green',bins=100, kde=True)
dfm[dfm['event'] == 0]['event_return'].mean()
# Out:
# 0.04574705818955163

# %% [markdown]
# # Cannot reject null hypothesis
